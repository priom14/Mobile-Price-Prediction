# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data//train.csv")

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.3 KB

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df_categorical = df[['price_range', 'n_cores', 'blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']]

# %%
unique_counts = df_categorical.nunique()
unique_values = df_categorical.apply(lambda x: x.unique())
pd.DataFrame({'Number of Unique Values': unique_counts, 'Unique Values': unique_values})
# Out:
#               Number of Unique Values             Unique Values
# price_range                         4              [1, 2, 3, 0]
# n_cores                             8  [2, 3, 5, 6, 1, 8, 4, 7]
# blue                                2                    [0, 1]
# dual_sim                            2                    [0, 1]
# four_g                              2                    [0, 1]
# three_g                             2                    [0, 1]
# touch_screen                        2                    [0, 1]
# wifi                                2                    [1, 0]

# %%
df_numerical = df.drop(df_categorical.columns, axis=1)

# %%
df_numerical.describe()
# Out:
#        battery_power  clock_speed           fc   int_memory        m_dep  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     1.522250     4.309500    32.046500     0.501750
# std       439.418206     0.816004     4.341444    18.145715     0.288416
# min       501.000000     0.500000     0.000000     2.000000     0.100000
# 25%       851.750000     0.700000     1.000000    16.000000     0.200000
# 50%      1226.000000     1.500000     3.000000    32.000000     0.500000
# 75%      1615.250000     2.200000     7.000000    48.000000     0.800000
# max      1998.000000     3.000000    19.000000    64.000000     1.000000
#
#          mobile_wt           pc    px_height     px_width          ram  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    140.249000     9.916500   645.108000  1251.515500  2124.213000
# std      35.399655     6.064315   443.780811   432.199447  1084.732044
# min      80.000000     0.000000     0.000000   500.000000   256.000000
# 25%     109.000000     5.000000   282.750000   874.750000  1207.500000
# 50%     141.000000    10.000000   564.000000  1247.000000  2146.500000
# 75%     170.000000    15.000000   947.250000  1633.000000  3064.500000
# max     200.000000    20.000000  1960.000000  1998.000000  3998.000000
#
#               sc_h         sc_w    talk_time
# count  2000.000000  2000.000000  2000.000000
# mean     12.306500     5.767000    11.011000
# std       4.213245     4.356398     5.463955
# min       5.000000     0.000000     2.000000
# 25%       9.000000     2.000000     6.000000
# 50%      12.000000     5.000000    11.000000
# 75%      16.000000     9.000000    16.000000
# max      19.000000    18.000000    20.000000

# %% [markdown]
# ## EDA

# %%
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df_numerical
# Out:
#       battery_power  clock_speed  fc  int_memory  m_dep  mobile_wt  pc  \
# 0               842          2.2   1           7    0.6        188   2
# 1              1021          0.5   0          53    0.7        136   6
# 2               563          0.5   2          41    0.9        145   6
# 3               615          2.5   0          10    0.8        131   9
# 4              1821          1.2  13          44    0.6        141  14
# ...             ...          ...  ..         ...    ...        ...  ..
# 1995            794          0.5   0           2    0.8        106  14
# 1996           1965          2.6   0          39    0.2        187   3
# 1997           1911          0.9   1          36    0.7        108   3
# 1998           1512          0.9   4          46    0.1        145   5
# 1999            510          2.0   5          45    0.9        168  16
#
#       px_height  px_width   ram  sc_h  sc_w  talk_time
# 0            20       756  2549     9     7         19
# 1           905      1988  2631    17     3          7
# 2          1263      1716  2603    11     2          9
# 3          1216      1786  2769    16     8         11
# 4          1208      1212  1411     8     2         15
# ...         ...       ...   ...   ...   ...        ...
# 1995       1222      1890   668    13     4         19
# 1996        915      1965  2032    11    10         16
# 1997        868      1632  3057     9     1          5
# 1998        336       670   869    18    10         19
# 1999        483       754  3919    19     4          2
#
# [2000 rows x 13 columns]

# %%
fig, ax = plt.subplots(7, 2, figsize=(40, 50))
ax = ax.flatten()  # Flatten the 2D array of axes to 1D

for i, col in enumerate(df_numerical.columns):  # Use .columns if df_numerical is a DataFrame
    sns.histplot(df_numerical[col], ax=ax[i])   # Use ax[i] to refer to individual axes
    ax[i].set_title(f'Histogram of {col}', fontsize=16)  # Set title
    ax[i].set_xlabel(f'{col}', fontsize=14)  # Set x-axis label
    ax[i].set_ylabel('Frequency', fontsize=14) 

plt.tight_layout()
plt.show()

# %%
plt.figure (figsize = (6 , 5) , dpi = 100)
heatmap = sns.heatmap (df.corr()[['price_range']].sort_values (by = 'price_range', ascending = False), vmin = -1, vmax = 1, annot = True, cmap = 'GnBu')
heatmap.set_title ('Features Correlating with Price Range', fontdict = {'fontsize':12} , pad = 18);

# %%
fig=plt.figure(figsize=(25,20))
for i,col in enumerate(df_numerical):
    ax=fig.add_subplot(5,3,i+1)
    ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
    sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
    sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
    sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df[col][df['price_range']==1],hist=False, kde=True,color='cadetblue')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==2],hist=False, kde=True,color='teal')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==3],hist=False, kde=True,color='lightseagreen')
# C:\Users\HP\AppData\Local\Temp\ipykernel_24436\4216559911.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col][df['price_range']==4],hist=False, kde=True,color='darkseagreen')

# %%
columns = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']
palette ="GnBu"
for column in columns:
    plt.figure(figsize=(15,2))
    sns.boxplot(x=df[column], palette=palette)
    plt.title(column)
    stats = df[column].describe()
    stats_text = ", ".join([f"{key}: {value:.2f}" for key, value in stats.items()])
    print(f"\n{column} Statistics:\n{stats_text}")
    plt.show()
# Out:
# battery_power Statistics:
# count: 2000.00, mean: 1238.52, std: 439.42, min: 501.00, 25%: 851.75, 50%: 1226.00, 75%: 1615.25, max: 1998.00
# blue Statistics:
# count: 2000.00, mean: 0.49, std: 0.50, min: 0.00, 25%: 0.00, 50%: 0.00, 75%: 1.00, max: 1.00
# clock_speed Statistics:
# count: 2000.00, mean: 1.52, std: 0.82, min: 0.50, 25%: 0.70, 50%: 1.50, 75%: 2.20, max: 3.00
# dual_sim Statistics:
# count: 2000.00, mean: 0.51, std: 0.50, min: 0.00, 25%: 0.00, 50%: 1.00, 75%: 1.00, max: 1.00
# fc Statistics:
# count: 2000.00, mean: 4.31, std: 4.34, min: 0.00, 25%: 1.00, 50%: 3.00, 75%: 7.00, max: 19.00
# four_g Statistics:
# count: 2000.00, mean: 0.52, std: 0.50, min: 0.00, 25%: 0.00, 50%: 1.00, 75%: 1.00, max: 1.00
# int_memory Statistics:
# count: 2000.00, mean: 32.05, std: 18.15, min: 2.00, 25%: 16.00, 50%: 32.00, 75%: 48.00, max: 64.00
# m_dep Statistics:
# count: 2000.00, mean: 0.50, std: 0.29, min: 0.10, 25%: 0.20, 50%: 0.50, 75%: 0.80, max: 1.00
# mobile_wt Statistics:
# count: 2000.00, mean: 140.25, std: 35.40, min: 80.00, 25%: 109.00, 50%: 141.00, 75%: 170.00, max: 200.00
# n_cores Statistics:
# count: 2000.00, mean: 4.52, std: 2.29, min: 1.00, 25%: 3.00, 50%: 4.00, 75%: 7.00, max: 8.00
# pc Statistics:
# count: 2000.00, mean: 9.92, std: 6.06, min: 0.00, 25%: 5.00, 50%: 10.00, 75%: 15.00, max: 20.00
# px_height Statistics:
# count: 2000.00, mean: 645.11, std: 443.78, min: 0.00, 25%: 282.75, 50%: 564.00, 75%: 947.25, max: 1960.00
# px_width Statistics:
# count: 2000.00, mean: 1251.52, std: 432.20, min: 500.00, 25%: 874.75, 50%: 1247.00, 75%: 1633.00, max: 1998.00
# ram Statistics:
# count: 2000.00, mean: 2124.21, std: 1084.73, min: 256.00, 25%: 1207.50, 50%: 2146.50, 75%: 3064.50, max: 3998.00
# sc_h Statistics:
# count: 2000.00, mean: 12.31, std: 4.21, min: 5.00, 25%: 9.00, 50%: 12.00, 75%: 16.00, max: 19.00
# sc_w Statistics:
# count: 2000.00, mean: 5.77, std: 4.36, min: 0.00, 25%: 2.00, 50%: 5.00, 75%: 9.00, max: 18.00
# talk_time Statistics:
# count: 2000.00, mean: 11.01, std: 5.46, min: 2.00, 25%: 6.00, 50%: 11.00, 75%: 16.00, max: 20.00
# three_g Statistics:
# count: 2000.00, mean: 0.76, std: 0.43, min: 0.00, 25%: 1.00, 50%: 1.00, 75%: 1.00, max: 1.00
# touch_screen Statistics:
# count: 2000.00, mean: 0.50, std: 0.50, min: 0.00, 25%: 0.00, 50%: 1.00, 75%: 1.00, max: 1.00
# wifi Statistics:
# count: 2000.00, mean: 0.51, std: 0.50, min: 0.00, 25%: 0.00, 50%: 1.00, 75%: 1.00, max: 1.00

# %% [markdown]
# ## Models

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
X = df.drop(columns = ['price_range'], axis = 1)
Y = df['price_range']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
print('number of rows in train data is', X_train.shape)
print('number of rows in test data is', X_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# number of rows in train data is (1400, 20)
# number of rows in test data is (600, 20)
# y_train shape: (1400,)
# y_test shape: (600,)

# %%
DT_model = DecisionTreeClassifier()
DT_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DT_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('\33[46mModel Accuracy Score: {0:0.5f}'. format(accuracy_score(y_test, y_pred)))
print('training set score: {:.5f}'.format(DT_model.score(X_train, y_train)))
print('test set score: {:.5f}'.format(DT_model.score(X_test, y_test)))
# Out:
# Model Accuracy Score: 0.82167
# training set score: 1.00000
# test set score: 0.82167

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle=False) #cross-validation
score = cross_val_score(DT_model, X_train, y_train, cv=kf, scoring='accuracy')
DT_model_cv_score = score.mean()
DT_model_cv_stdev = np.std(score)
print('cross validation accuracy scores are:\n {}'.format(score))
# Out:
# cross validation accuracy scores are:
#  [0.79285714 0.81428571 0.85       0.85714286 0.80714286 0.85
#  0.8        0.86428571 0.80714286 0.80714286]

# %%
accuracy = ['CV Accuracy']
DT_A = pd.DataFrame({'CV MEAM':DT_model_cv_score,'STD':DT_model_cv_stdev},index=accuracy)
DT_A
# Out:
#              CV MEAM       STD
# CV Accuracy    0.825  0.025605

# %%
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
plt.figure(figsize=(12, 8))
sns.set(font_scale=1.2)
ConfusionMatrixDisplay.from_estimator(DT_model, X_test, y_test, colorbar=False, cmap='GnBu')
plt.title('Confusion Matrix of Base Decision Tree')
plt.grid(False)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       151
#            1       0.73      0.80      0.76       135
#            2       0.77      0.72      0.75       151
#            3       0.88      0.88      0.88       163
#
#     accuracy                           0.82       600
#    macro avg       0.82      0.82      0.82       600
# weighted avg       0.82      0.82      0.82       600

# %%
from sklearn.tree import plot_tree
feature_names = ['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']
target_names = ["0", "1", "2", "3"]
fig = plt.figure(figsize = (30, 15))
Plot = plot_tree (DT_model, feature_names = feature_names, class_names = target_names, filled = True)

# %%
importances = DT_model.feature_importances_ # feature importances
indices = np.argsort(importances) #sort
plt.figure(figsize=(10, 6))
plt.barh(range(len(indices)), importances[indices], color='#52796f', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
for i, v in enumerate(importances[indices]):
    plt.text(v, i, str(round(v, 3)), color='black', fontsize= 8)
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
def metrics_calculator(y_test, y_pred, model_name):
    result = pd.DataFrame(data=[accuracy_score(y_test, y_pred),
                                precision_score(y_test, y_pred, average='macro'),
                                recall_score(y_test, y_pred, average='macro'),
                                f1_score(y_test, y_pred, average='macro')],
                          index=['Accuracy','Precision','Recall','F1-score'],
                          columns = [model_name])
    return result

# %%
BaseDT = metrics_calculator(y_test, y_pred, 'Base Decision Tree')
BaseDT
# Out:
#            Base Decision Tree
# Accuracy             0.821667
# Precision            0.819682
# Recall               0.819987
# F1-score             0.819190

# %% [markdown]
# ### Random Forest Classifier

# %%
RF_model = RandomForestClassifier()
RF_model.fit(X_train, y_train) # fit model
# Out:
# RandomForestClassifier()

# %%
y_pred = RF_model.predict(X_test)

# %%
print('\33[46mModel Accuracy Score: {0:0.5f}'. format(accuracy_score(y_test, y_pred)))
print('training set score: {:.5f}'.format(RF_model.score(X_train, y_train)))
print('test set score: {:.5f}'.format(RF_model.score(X_test, y_test)))
shapes = {
    'X_train': X_train.shape[0],
    'y_train': y_train.shape[0],
    'X_test': X_test.shape[0],
    'y_test': y_test.shape[0]}
plt.figure(figsize=(16, 6))
plt.bar(shapes.keys(), shapes.values(),color="darkseagreen")
plt.ylabel('Count')
plt.title('Distribution of Training & Validation Sets')
plt.show()
# Out:
# Model Accuracy Score: 0.87333
# training set score: 1.00000
# test set score: 0.87333

# %%
kf = KFold(n_splits=10, shuffle=False) #cross-validation
score = cross_val_score(RF_model, X_train, y_train, cv=kf, scoring='accuracy')
RF_model_cv_score = score.mean()
RF_model_cv_stdev = np.std(score)
print('cross validation accuracy scores are:\n {}'.format(score))
# Out:
# cross validation accuracy scores are:
#  [0.89285714 0.82142857 0.86428571 0.87857143 0.82142857 0.82142857
#  0.85       0.90714286 0.85714286 0.88571429]

# %%
Accuracy = ['CV Accuracy']
RFA = pd.DataFrame({'CV Mean':RF_model_cv_score,'STD':RF_model_cv_stdev},index=Accuracy)
RFA
# Out:
#              CV Mean       STD
# CV Accuracy     0.86  0.029829

# %%
plt.figure(figsize=(12, 8))
sns.set(font_scale=1.2)
ConfusionMatrixDisplay.from_estimator(RF_model, X_test, y_test, colorbar=False, cmap='GnBu')
plt.title('Confusion Matrix of Tuned Decision Tree')
plt.grid(False)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       151
#            1       0.82      0.81      0.82       135
#            2       0.81      0.78      0.79       151
#            3       0.91      0.92      0.92       163
#
#     accuracy                           0.87       600
#    macro avg       0.87      0.87      0.87       600
# weighted avg       0.87      0.87      0.87       600

# %%
BaseRF = metrics_calculator(y_test, y_pred, 'Base Random Forest')
BaseRF
# Out:
#            Base Random Forest
# Accuracy             0.873333
# Precision            0.869912
# Recall               0.870851
# F1-score             0.870257

# %%
importances = RF_model.feature_importances_ # feature importances
indices = np.argsort(importances) #sort
plt.figure(figsize=(10, 6))
plt.barh(range(len(indices)), importances[indices], color='#52796f', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
for i, v in enumerate(importances[indices]):
    plt.text(v, i, str(round(v, 3)), color='black', fontsize= 8)
plt.show()
